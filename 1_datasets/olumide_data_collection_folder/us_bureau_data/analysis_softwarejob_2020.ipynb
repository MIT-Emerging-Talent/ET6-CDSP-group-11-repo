# %%
import pandas as pd

# %%
df = pd.read_csv(
    "/Users/user/Documents/mit_stuff/CDSP_GROUP_11/ET6-CDSP-group-11-repo/1_datasets/olumide_data_collection_folder/us_bureau_data/usa_national_annual_wage_softwarejob_2020.csv"
)

# %%
df.head()
# Out:
#   area_fips  own_code industry_code  agglvl_code  size_code  year qtr  \
# 0     US000         0            10           10          0  2020   A
# 1     US000         1            10           11          0  2020   A
# 2     US000         1           101           12          0  2020   A
# 3     US000         1          1011           13          0  2020   A
# 4     US000         1          1012           13          0  2020   A
#
#   disclosure_code  annual_avg_estabs  annual_avg_emplvl  ...  \
# 0             NaN           10487687          139103773  ...
# 1             NaN              61310            2928036  ...
# 2             NaN                123              54617  ...
# 3             NaN                 75               3665  ...
# 4             NaN                  1                  4  ...
#
#    oty_total_annual_wages_chg  oty_total_annual_wages_pct_chg  \
# 0                136497892833                             1.6
# ...

# %%
df.describe()
# Out:
#           own_code  agglvl_code  size_code    year  annual_avg_estabs  \
# count  4547.000000  4547.000000     4547.0  4547.0       4.547000e+03
# mean      3.540576    17.052782        0.0  2020.0       2.311818e+04
# std       1.514649     1.974504        0.0     0.0       3.091189e+05
# min       0.000000    10.000000        0.0  2020.0       0.000000e+00
# 25%       2.000000    16.000000        0.0  2020.0       9.000000e+00
# 50%       3.000000    17.000000        0.0  2020.0       3.880000e+02
# 75%       5.000000    18.000000        0.0  2020.0       3.979500e+03
# max       9.000000    95.000000        0.0  2020.0       1.048769e+07
#
#        annual_avg_emplvl  total_annual_wages  taxable_annual_wages  \
# count       4.547000e+03        4.547000e+03          4.547000e+03
# mean        3.098482e+05        1.981779e+10          3.749434e+09
# std         3.832993e+06        2.443478e+11          4.957186e+10
# ...

# %%
columns_to_keep = [
    "area_fips",
    "year",
    "industry_code",
    "annual_avg_emplvl",
    "annual_avg_wkly_wage",
    "avg_annual_pay",
    "oty_annual_avg_emplvl_chg",
    "oty_annual_avg_emplvl_pct_chg",
    "oty_annual_avg_wkly_wage_chg",
    "oty_annual_avg_wkly_wage_pct_chg",
]

# %%
df = df[columns_to_keep]

# %%
df.head(20)
# Out:
#    area_fips  year industry_code  annual_avg_emplvl  annual_avg_wkly_wage  \
# 0      US000  2020            10          139103773                  1231
# 1      US000  2020            10            2928036                  1644
# 2      US000  2020           101              54617                  1663
# 3      US000  2020          1011               3665                  1459
# 4      US000  2020          1012                  4                  2779
# 5      US000  2020          1013              50949                  1677
# 6      US000  2020           102            2873419                  1643
# 7      US000  2020          1021             670382                  1250
# 8      US000  2020          1022               6640                  1611
# 9      US000  2020          1023              12095                  2403
# 10     US000  2020          1024              69044                  1769
# 11     US000  2020          1025             425315                  1670
# ...
