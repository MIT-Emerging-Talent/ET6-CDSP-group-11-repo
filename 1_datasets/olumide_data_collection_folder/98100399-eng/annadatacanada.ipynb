# %%
import pandas as pd

# %%
df = pd.read_csv(
    "/Users/user/Documents/mit_stuff/CDSP_GROUP_11/ET6-CDSP-group-11-repo/1_datasets/olumide_data_collection_folder/98100399-eng/98100399.csv"
)

# %%
df.head()
# Out:
#    REF_DATE     GEO           DGUID      Gender (3)    Age (15A)  \
# 0      2021  Canada  2021A000011124  Total - Gender  Total - Age
# 1      2021  Canada  2021A000011124  Total - Gender  Total - Age
# 2      2021  Canada  2021A000011124  Total - Gender  Total - Age
# 3      2021  Canada  2021A000011124  Total - Gender  Total - Age
# 4      2021  Canada  2021A000011124  Total - Gender  Total - Age
#
#        Employment income statistics (7)     Immigrant status (4A)  \
# 0  Total - Employment income statistics  Total - Immigrant status
# 1  Total - Employment income statistics  Total - Immigrant status
# 2  Total - Employment income statistics  Total - Immigrant status
# 3  Total - Employment income statistics  Total - Immigrant status
# 4  Total - Employment income statistics  Total - Immigrant status
#
#        Location of study (5)  \
# 0  Total - Location of study
# 1  Total - Location of study
# 2  Total - Location of study
# 3  Total - Location of study
# ...

# %%
df.describe()
# Out:
#          REF_DATE  Visible minority (15):Total - Visible minority[1]  \
# count  19756800.0                                       1.948543e+07
# mean       2021.0                                       1.252002e+04
# std           0.0                                       6.810892e+04
# min        2021.0                                      -1.300000e+05
# 25%        2021.0                                       0.000000e+00
# 50%        2021.0                                       0.000000e+00
# 75%        2021.0                                       2.200000e+03
# max        2021.0                                       3.033592e+07
#
#        Visible minority (15):Total visible minority population[2]  \
# count                                       1.950452e+07
# mean                                        6.634082e+03
# std                                         2.438899e+04
# min                                        -1.200000e+05
# ...
